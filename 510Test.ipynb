# %% [markdown]
# <a href="https://colab.research.google.com/github/acpotgieter/geog510/blob/Lab-2/510Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("510 Test Colab")
# Out:
# 510 Test Colab
